# %%
a = 8
type(a)
# Out:
# int

# %%
b = "cos'è questa cosa?"
type(b)
# Out:
# str

# %%
c = 7.7
type(c)
# Out:
# float

# %%
d = [a, b, c]
type(d)
# Out:
# list

# %%
type(d[0])
# Out:
# int

# %%
d[-1]
# Out:
# 7.7
